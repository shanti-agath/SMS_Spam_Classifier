# %%
import pandas as pd
import numpy as np
import re
import nltk

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('stopwords')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 4
#       2 import numpy as np
#       3 import re
# ----> 4 import nltk
#       6 from sklearn.model_selection import train_test_split
#       7 from sklearn.feature_extraction.text import TfidfVectorizer
#
# ModuleNotFoundError: No module named 'nltk'

# %%
df = pd.read_csv("../data/sms_spam.csv")
df.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    words = text.split()
    words = [stemmer.stem(word) for word in words if word not in stop_words]
    return " ".join(words)

df['clean_text'] = df['text'].apply(clean_text)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 stemmer = PorterStemmer()
#       2 stop_words = set(stopwords.words('english'))
#       4 def clean_text(text):
#
# NameError: name 'PorterStemmer' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df['clean_text'], df['label'], test_size=0.2, random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(
#       2     df['clean_text'], df['label'], test_size=0.2, random_state=42
#       3 )
#
# NameError: name 'train_test_split' is not defined

# %%
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 vectorizer = TfidfVectorizer()
#       2 X_train_vec = vectorizer.fit_transform(X_train)
#       3 X_test_vec = vectorizer.transform(X_test)
#
# NameError: name 'TfidfVectorizer' is not defined

# %%
nb_model = MultinomialNB()
nb_model.fit(X_train_vec, y_train)

y_pred_nb = nb_model.predict(X_test_vec)

print("Naive Bayes Accuracy:", accuracy_score(y_test, y_pred_nb))
print(classification_report(y_test, y_pred_nb))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 nb_model = MultinomialNB()
#       2 nb_model.fit(X_train_vec, y_train)
#       4 y_pred_nb = nb_model.predict(X_test_vec)
#
# NameError: name 'MultinomialNB' is not defined

# %%
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train_vec, y_train)

y_pred_lr = lr_model.predict(X_test_vec)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 lr_model = LogisticRegression(max_iter=1000)
#       2 lr_model.fit(X_train_vec, y_train)
#       4 y_pred_lr = lr_model.predict(X_test_vec)
#
# NameError: name 'LogisticRegression' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test, y_pred_lr)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Logistic Regression")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#       4 cm = confusion_matrix(y_test, y_pred_lr)
#       6 plt.figure(figsize=(5,4))
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
test_msgs = [
    "Congratulations! You won a free ticket",
    "Hey, are we meeting today?",
    "Win cash prize now!!!"
]

test_clean = [clean_text(msg) for msg in test_msgs]
test_vec = vectorizer.transform(test_clean)

predictions = lr_model.predict(test_vec)

for msg, pred in zip(test_msgs, predictions):
    print(f"Message: {msg}")
    print(f"Prediction: {pred}")
    print()

# %%
import pickle

with open("../models/spam_model.pkl", "wb") as f:
    pickle.dump(lr_model, f)

with open("../models/tfidf_vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 import pickle
#       3 with open("../models/spam_model.pkl", "wb") as f:
# ----> 4     pickle.dump(lr_model, f)
#       6 with open("../models/tfidf_vectorizer.pkl", "wb") as f:
#       7     pickle.dump(vectorizer, f)
#
# NameError: name 'lr_model' is not defined
